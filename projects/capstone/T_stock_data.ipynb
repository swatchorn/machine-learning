# %%
# Matplotlib for plotting
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from stock_data import ATT

# %%
# T is in the defaul quandl WIKI database
att = ATT(ticker='T')
# Out:
# T Stock Initialized. Data covers 1984-07-19 00:00:00 to 2018-03-27 00:00:00.

# %%
# Stock attributes 
stock_history = att.stock
stock_history.head()
# Out:
#         Date   Open   High    Low  Close    Volume  Ex-Dividend  Split Ratio  \
# 0 1984-07-19  59.75  59.87  59.38  59.38   77900.0          0.0          1.0
# 1 1984-07-20  59.62  60.00  59.25  59.50  129800.0          0.0          1.0
# 2 1984-07-23  59.25  59.75  58.75  59.50  276100.0          0.0          1.0
# 3 1984-07-24  59.75  60.38  59.62  60.00  129100.0          0.0          1.0
# 4 1984-07-25  60.00  61.37  59.87  60.75  152400.0          0.0          1.0
#
#    Adj. Open  Adj. High  Adj. Low  Adj. Close  Adj. Volume         ds  \
# 0   1.275248   1.277809  1.267351    1.267351     934800.0 1984-07-19
# 1   1.272474   1.280584  1.264577    1.269913    1557600.0 1984-07-20
# 2   1.264577   1.275248  1.253905    1.269913    3313200.0 1984-07-23
# 3   1.275248   1.288694  1.272474    1.280584    1549200.0 1984-07-24
# 4   1.280584   1.309824  1.277809    1.296591    1828800.0 1984-07-25
#
#           y  Daily Change
# 0  1.267351     -0.007897
# 1  1.269913     -0.002561
# ...

# %%
#plot stock history adjusted close
att.plot_stock()
# Out:
# Maximum Adj. Close = 41.03 on 2017-03-17 00:00:00.
# Minimum Adj. Close = 1.27 on 1984-07-19 00:00:00.
# Current Adj. Close = 34.90 on 2018-03-27 00:00:00.

# %%
#Plot the daily changes for a period of 1 yr
att.plot_stock(start_date = '2017-03-28',  end_date = '2018-03-27',  stats = ['Daily Change', 'Adj. Volume'],  plot_type='pct')
# Out:
# Maximum Daily Change = 1.19 on 2017-07-27 00:00:00.
# Minimum Daily Change = -1.63 on 2017-10-12 00:00:00.
# Current Daily Change = 0.05 on 2018-03-27 00:00:00.
#
# Maximum Adj. Volume = 91170783.00 on 2017-10-25 00:00:00.
# Minimum Adj. Volume = 9203078.00 on 2017-11-24 00:00:00.
# Current Adj. Volume = 33198184.00 on 2018-03-27 00:00:00.
